# %%
import folium
import branca
import ela
import pandas as pd
import branca.colormap as cm

# %%
gen_df = ela.gen_data
stor_df = ela.stor_data

# %%
#gen_df = gen_df[gen_df.state=="CA"]

# %%
def gen_statewise(state):
    gen_df = ela.gen_data
    gen_df = gen_df[gen_df.state==state]
    levels, labels = pd.factorize(gen_df.type)
    lats = gen_df.lat
    lons = gen_df.lon
    colors = levels
    step = cm.StepColormap(['b','r','y','g','m','c','k'],vmin=0,vmax=7)
    f = folium.map.FeatureGroup()

    for lat, lon, color in zip(lats, lons, colors):
        f.add_child(
         folium.features.CircleMarker(
            [lat, lon],
            radius=3,
            color=None,
            fill_color=step(color)
            )
    )
        
    m= folium.Map([36,-120], zoom_start=3)
    m.add_child(f)
    return m

# %%
gen_statewise('CA')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
stor_df = ela.stor_data
stor_df=stor_df[stor_df.state=='New York']
stor_df
# Out:
#                                                   name        lat        lon  \
# 1              Next Gen CAES using Steel Piping - NYPA  40.728224 -73.794852
# 3               NYSEG Seneca/Watkins Glen CAES Project  42.415934 -76.896832
# 4    Con Edison/Eos Energy Storage Distributed Ener...  40.714353 -74.005973
# 46                 BMCC Urban Electric 100 kW New York  40.712784 -74.005941
# 53                  2 MW Potsdam, New York - Microgrid  44.669781 -74.981308
# 55        Red Hook (Brooklyn, NY) - NY Prize Microgrid  40.677280 -74.009447
# 57   Long Island Community Microgrid Project - 5 MW...  40.963434 -72.184801
# 92                            Deepwater Wind-New York   41.035935 -71.954515
# 102                      Queens College-CUNY PV System  40.712784 -74.005941
# 114        Ultralife SUNY Canton Wind Integration Demo  44.608012 -75.184657
# 138  500 kW / 800 kWh - Electrovaya Transportable E...  40.712784 -74.005941
# 165                  Beacon Power - (Stephentown, NY)   42.553916 -73.394447
# 194                               Long Island Bus BESS  40.726768 -73.634295
# 206           LIRR Malverne WESS: Maxwell Technologies  40.675407 -73.669220
# 216  7-Eleven Distributed Energy Storage System (DE...  40.754233 -73.900612
# 217  La Guardia Airport Avis Car Rental - Green Cha...  40.775852 -73.883958
# 247                     Lewiston Pump-Generating Plant  43.142984 -79.021806
# 268       Blenheim-Gilboa Pumped Storage Power Project  42.442978 -74.448187
# 328                                      Barclay Tower  40.712320 -74.008823
# 330                             UEP CCNY Demonstration  40.819547 -73.949518
# 339  Long Island Power Authority Long Island Smart ...  40.723300 -73.593582
# 340  ConEdison Interoperability of Demand Response ...  40.713828 -74.013166
# 342  Green Charge Networks Lithium Ion Distributed ...  40.744869 -73.776886
# 361            Schooner America 2.0 Electric Populsion  40.748127 -74.008315
# 371                    Arista Durathon Battery Project  43.191445 -77.660869
# 379             Green Charge Networks (Yonkers Site 1)  40.959840 -73.880130
# 435  Brooklyn Army Terminal Smart Grid Demonstratio...  40.643967 -74.024797
# 450  American Vanadium Corp. MTA CellCube Installation  40.704597 -74.013067
# 488                                   Rose City Lights  40.744365 -73.957176
# 527                          LIRR Malverne WESS: Ioxus  40.675407 -73.669220
# 549         Green Charge Networks (43rd Street Site 1)  40.762173 -73.999345
# 55     Announced                         Electric Energy Time Shift
# 57     Announced  Grid-Connected Commercial (Reliability & Quali...
# 92     Announced                        Renewables Capacity Firming
# 102    Announced           Electric Bill Management with Renewables
# 114   Contracted               Onsite Renewable Generation Shifting
# 138   Contracted                                      On-Site Power
# 165  Operational                               Frequency Regulation
# 194  Operational                                        Black Start
# 206  Operational                            Transportation Services
# 216  Operational                           Electric Bill Management
# 217  Operational                           Electric Bill Management
# 247  Operational                         Electric Energy Time Shift
# 268  Operational                         Electric Energy Time Shift
# 328  Operational                           Electric Bill Management
# 330  Operational                           Electric Bill Management
# 339  Operational                         Electric Energy Time Shift
# 340  Operational                           Electric Bill Management
# 342  Operational                           Electric Bill Management
# 361  Operational                                      On-Site Power
# 371  Operational                           Electric Bill Management
# 379  Operational                           Electric Bill Management
# 435  Operational           Electric Bill Management with Renewables
# 450  Operational  Grid-Connected Commercial (Reliability & Quali...
# 488  Operational                           Electric Bill Management
# 527  Operational                            Transportation Services
# 549  Operational                           Electric Bill Management
# 550  Operational                           Electric Bill Management
# 551  Operational                           Electric Bill Management
# 590  Operational                           Electric Bill Management
# 591  Operational                                    Demand Response
# 594  Operational                           Electric Bill Management
# 620  Operational                               Microgrid Capability
# 652  Operational                         Electric Energy Time Shift
# 660  Operational                           Electric Bill Management
#
#                    city     state
# 1                Queens  New York
# 3               Reading  New York
# 4              New York  New York
# 46        New York City  New York
# 53              Potsdam  New York
# 55   Red Hook, Brooklyn  New York
# 57         East Hampton  New York
# 92              Montauk  New York
# 102            New York  New York
# 114              Canton  New York
# 138            New York  New York
# 165         Stephentown  New York
# 194         Garden City  New York
# 206            Malverne  New York
# 216            Woodside  New York
# 217              Queens  New York
# 247            Lewiston  New York
# 268      North Blenheim  New York
# 328            New York  New York
# 330            New York  New York
# 339           Uniondale  New York
# 340            New York  New York
# 342              Queens  New York
# 361            New York  New York
# 371           Rochester  New York
# 379             Yonkers  New York
# 435            Brooklyn  New York
# 450            New York  New York
# 488    Long Island City  New York
# 527            Malverne  New York
# 549            New York  New York
# 550            New York  New York
# 551            New York  New York
# 590       New York City  New York
# 591           Manhattan  New York
# 594            New York  New York
# 620             Warwick  New York
# 652            Brooklyn  New York
# 660             Yonkers  New York

# %%
def stor_statewise(state):
    stor_df = ela.stor_data
    stor_df = stor_df[stor_df.state==state]
    levels, labels = pd.factorize(stor_df.type)
    lats = stor_df.lat
    lons = stor_df.lon
    colors = levels
    step = cm.StepColormap(['b','r','y','g','m','c','k'],vmin=0,vmax=7)
    f = folium.map.FeatureGroup()

    for lat, lon, color in zip(lats, lons, colors):
        f.add_child(
         folium.features.CircleMarker(
            [lat, lon],
            radius=3,
            color=None,
            fill_color=step(color)
            )
    )
        
    m= folium.Map([46,-70], zoom_start=3)
    m.add_child(f)
    return m

# %%
stor_statewise('New York')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
labels
# Out:
# Index(['SOLAR', '0', 'WIND', 'HYDRO', 'OTHF', 'COAL', 'GAS', 'GEOTHERMAL',
#        'BIOMASS', 'OFSL', 'OIL', 'NUCLEAR'],
#       dtype='object')
