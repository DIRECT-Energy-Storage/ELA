# %%
import folium
import branca
import ela
import pandas as pd
import branca.colormap as cm
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

# %%
import IPython.display
IPython.display.Image(filename='Legend_Gen.png')

# %%
red_patch = mpatches.Patch(color='#b9341b', label='Nuclear')
yellow_patch = mpatches.Patch(color='#f6cc0a',label='Solar')
green_patch = mpatches.Patch(color='#55b64e', label='Biomass')
blue_patch = mpatches.Patch(color='#2B90F5', label='Hydro')
orange_patch = mpatches.Patch(color='#ff6700', label='Oil')
black_patch = mpatches.Patch(color='#000000', label='Other')
pink_patch = mpatches.Patch(color='#fe7b89', label='Coal')
purple_patch = mpatches.Patch(color='#d400ee', label='Geothermal')
mint_patch = mpatches.Patch(color='#b9eeb7', label='Wind')
darkg_patch = mpatches.Patch(color='#283b1a', label='Gas')

plt.legend(handles=[yellow_patch,red_patch,green_patch,blue_patch,orange_patch,black_patch,pink_patch,purple_patch,mint_patch,darkg_patch],loc=10,prop={'size':14})
#plt.show()

# %%
def gen_statewise(state):
    gen_df = ela.gen_data
    gen_df = gen_df[gen_df.state==state]
    m=folium.Map()
    for index,rows in gen_df.iterrows():
        f = folium.map.FeatureGroup()
        if rows[5]=='Solar':
            f.add_child(folium.features.CircleMarker([rows[3],rows[4]],radius=3,fill_color='#f6cc0a')) #YELLOW
            m.add_child(f)
        elif rows[5]=='Hydro':
            f.add_child(folium.features.CircleMarker([rows[3],rows[4]],radius=3,fill_color='#2B90F5')) #BLUE
            m.add_child(f)
        elif rows[5]=='Nuclear':
            f.add_child(folium.features.CircleMarker([rows[3],rows[4]],radius=3,fill_color='#b9341b')) #RED
            m.add_child(f)
        elif rows[5]=='Biomass':
            f.add_child(folium.features.CircleMarker([rows[3],rows[4]],radius=3,fill_color='#55b64e')) #GREEN
            m.add_child(f)
        elif rows[5]=='Oil':
            f.add_child(folium.features.CircleMarker([rows[3],rows[4]],radius=3,fill_color='#ff6700')) #ORANGE
            m.add_child(f)
        elif rows[5]=='Coal':
            f.add_child(folium.features.CircleMarker([rows[3],rows[4]],radius=3,fill_color='#fe7b89')) #PINK
            m.add_child(f)
        elif rows[5]=='Geothermal':
            f.add_child(folium.features.CircleMarker([rows[3],rows[4]],radius=3,fill_color='#d400ee')) #PURPLE
            m.add_child(f)
        elif rows[5]=='Wind':
            f.add_child(folium.features.CircleMarker([rows[3],rows[4]],radius=3,fill_color='#b9eeb7')) #MINT
            m.add_child(f)
        elif rows[5]=='Other':
            f.add_child(folium.features.CircleMarker([rows[3],rows[4]],radius=3,fill_color='#000000')) #BLACK
            m.add_child(f)
        elif rows[5]=='Gas':
            f.add_child(folium.features.CircleMarker([rows[3],rows[4]],radius=3,fill_color='#283b1a')) #DARKGREEN
            m.add_child(f)
        
        else:
            pass
    return m

# %%
gen_statewise('IN')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
stor_df = ela.stor_data
stor_df
# Out:
#      Unnamed: 0                                               name        lat  \
# 0             0  PG&E Advanced Underground Compressed Air Energ...  37.917594
# 1             1            Next Gen CAES using Steel Piping - NYPA  40.728224
# 2             2              Lake Elsinore Advanced Pumped Storage  33.668077
# 3             3             NYSEG Seneca/Watkins Glen CAES Project  42.415934
# 4             4  Con Edison/Eos Energy Storage Distributed Ener...  40.714353
# 5             5                          Apex Bethel Energy Center  31.835445
# 6             6                            Eldorado Pumped Storage  36.079561
# 7             7                          Prineville Pumped Storage  44.097813
# 8             8               Advanced Rail Energy Storage Nevada   36.208294
# 9             9  SolarCity / Tesla / Princeton Power Grid Servi...  37.548270
# 10           10  SolarCity / Tesla / Princeton Power EV Chargin...  37.548270
# 11           11                Silver Creek Pumped Storage Project  40.756454
# 12           12     Green Charge Networks GreenStation Announced 1  36.817759
# 13           13     Green Charge Networks GreenStation Announced 2  36.721382
# 14           14     Green Charge Networks GreenStation Announced 3  36.767092
# 680 -157.739444                  Electro-chemical      Electro-chemical
# 681  -88.608427               Lithium-ion Battery      Electro-chemical
#
#      power_kW duration              status  \
# 0      300000       10           Announced
# 1        9000      4.5           Announced
# 2      500000       12           Announced
# 3           0      n/a           Announced
# 4        1000        6           Announced
# 5      317000       96           Announced
# 6     1000000    10.33           Announced
# 7      150000      8.2           Announced
# 8       50000     0.25           Announced
# 9         200        1           Announced
# 10         30        1           Announced
# 11     300000        8           Announced
# 12        120        1           Announced
# 13         60        1           Announced
# 14         60        1           Announced
# 15         60        1           Announced
# 16        180        1           Announced
# 17        200        2           Announced
# 18         60        1           Announced
# 19         60        1           Announced
# 20        200        2           Announced
# 21        200        2           Announced
# 22         60        1           Announced
# 23       1000        2           Announced
# 24         60        2           Announced
# 25        200        2           Announced
# 26        200        2           Announced
# 27        400        2           Announced
# 28         90        2           Announced
# 29         60        2           Announced
# ..        ...      ...                 ...
# 652      1800     2.22         Operational
# 653        60        2         Operational
# 654      4000     0.42         Operational
# 655      1300        2         Operational
# 656      1000        6         Operational
# 657       250        6         Operational
# 658       500        2         Operational
# 659      1000      n/a         Operational
# 660        27     2.37         Operational
# 661      3517        4         Operational
# 662      3517        4         Operational
# 663       250        2         Operational
# 664        30      1.5         Operational
# 665      2000      n/a         Operational
# 666         6     2.37         Operational
# 667         0      n/a         Operational
# 668     20000        4         Operational
# 669      5000        4         Operational
# 670        36        4         Operational
# 671       500        1         Operational
# 672         0      n/a         Operational
# 673        15        8         Operational
# 674         1       25         Operational
# 675         5        1         Operational
# 676       500      0.5         Operational
# 677      6000        2  Under Construction
# 678       250        8  Under Construction
# 679      2600        1  Under Construction
# 680         0      n/a  Under Construction
# 681     20000     0.25  Under Construction
#
#                                                usecase                city  \
# 0                           Electric Energy Time Shift  San Joaquin County
# 1                                          Black Start              Queens
# 2                                 Frequency Regulation       Lake Elsinore
# 3                                 Frequency Regulation             Reading
# 4    Stationary Transmission/Distribution Upgrade D...            New York
# 5                                          Black Start    Tennessee Colony
# 6                             Electric Supply Capacity        Clark County
# 7                             Electric Supply Capacity        Crook County
# 8          Electric Supply Reserve Capacity - Spinning             Pahrump
# 9                             Electric Bill Management             Fremont
# 10                            Electric Bill Management             Fremont
# 11                        Renewables Energy Time Shift     Blythe Township
# 12                            Electric Bill Management              Fresno
# 13                            Electric Bill Management              Fresno
# 14                            Electric Bill Management              Fresno
# 15                            Electric Bill Management              Fresno
# 16                            Electric Bill Management              Fresno
# 17                            Electric Bill Management              Clovis
# 18                            Electric Bill Management              Clovis
# 19                            Electric Bill Management              Clovis
# 20                            Electric Bill Management              Clovis
# 21                            Electric Bill Management              Fresno
# 22                            Electric Bill Management              Fresno
# 23                            Electric Bill Management       San Francisco
# 24                            Electric Bill Management            Whittier
# 25                            Electric Bill Management             Ventura
# 26                            Electric Bill Management              Oxnard
# 27                            Electric Bill Management            Moorpark
# 28                            Electric Bill Management           San Diego
# 29                            Electric Bill Management           San Diego
# ..                                                 ...                 ...
# 652                         Electric Energy Time Shift            Brooklyn
# 653                           Electric Bill Management       Mission Viejo
# 654                               Frequency Regulation        Westminster
# 655                                    Demand Response              Irvine
# 656                           Electric Bill Management          Long Beach
# 657                           Electric Bill Management          Long Beach
# 658                           Electric Bill Management       San Francisco
# 659                           Electric Bill Management             Chicago
# 660                           Electric Bill Management             Yonkers
# 661                           Electric Bill Management              Pueblo
# 662                         Electric Energy Time Shift              Pueblo
# 663                           Electric Bill Management              Clovis
# 664                           Electric Bill Management              Basalt
# 665                         Electric Energy Time Shift             Gahanna
# 666                               Microgrid Capability              Duluth
# 667                           Electric Bill Management              Boston
# 668                           Electric Supply Capacity              Pomona
# 669                           Electric Supply Capacity         Santa Paula
# 670                                    Demand Response           San Diego
# 671               Onsite Renewable Generation Shifting         New Orleans
# 672                                    Demand Response         Bloomington
# 673                               Frequency Regulation         Maple Grove
# 674                               Microgrid Capability              Folsom
# 675                               Microgrid Capability          Sun Valley
# 676                                        Black Start    City of Commerce
# 677                         Electric Energy Time Shift             Redding
# 678  Grid-Connected Commercial (Reliability & Quali...            St. Paul
# 679                           Electric Bill Management         Los Angeles
# 680                           Electric Bill Management              Kailua
# 681                               Frequency Regulation             Marengo
#
#     state
# 0      AL
# 1      AL
# 2      AL
# 3      AK
# 4      AK
# 5      AK
# 6      AK
# 7      AK
# 8      AK
# 9      AK
# 10     AK
# 11     AK
# 12     AZ
# 13     AZ
# 14     AZ
# 15     AZ
# 16     AZ
# 17     AZ
# 18     AZ
# 19     AZ
# 20     AZ
# 21     AZ
# 22     AZ
# 23     AR
# 24     CA
# 25     CA
# 26     CA
# 27     CA
# 28     CA
# 29     CA
# ..    ...
# 652    VT
# 653    VA
# 654    VA
# 655    VA
# 656    VA
# 657    VA
# 658    VA
# 659    WA
# 660    WA
# 661    WA
# 662    WA
# 663    WA
# 664    WA
# 665    WA
# 666    WA
# 667    WA
# 668    WA
# 669    WA
# 670    WA
# 671    WA
# 672    WA
# 673    WA
# 674    WA
# 675    WA
# 676    WV
# 677    WV
# 678    WV
# 679    WV
# 680    WV
# 681    WI
#
# [682 rows x 12 columns]

# %%
def stor_statewise(state):
    stor_df = ela.stor_data
    stor_df = stor_df[stor_df.state==state]
    m=folium.Map()
    for index,rows in stor_df.iterrows():
        f = folium.map.FeatureGroup()
        if rows[5]=='Electro-mechanical':
            f.add_child(folium.features.CircleMarker([rows[2],rows[3]],radius=3,fill_color='#f6cc0a')) #YELLOW
            m.add_child(f)
        elif rows[5]=='Electro-chemical':
            f.add_child(folium.features.CircleMarker([rows[2],rows[3]],radius=3,fill_color='#2B90F5')) #BLUE
            m.add_child(f)
        elif rows[5]=='Pumped Hydro Storage':
            f.add_child(folium.features.CircleMarker([rows[2],rows[3]],radius=3,fill_color='#b9341b')) #RED
            m.add_child(f)
        elif rows[5]=='Thermal Storage':
            f.add_child(folium.features.CircleMarker([rows[2],rows[3]],radius=3,fill_color='#55b64e')) #GREEN
            m.add_child(f)
    return m

# %%
stor_statewise('WA')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
