# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('generation_data.csv')
df
# Out:
#       Unnamed: 0 state                                    name        lat  \
# 0              0    AK        Agrium Kenai Nitrogen Operations  60.673200
# 1              1    AK                                Alakanuk  62.683300
# 2              2    AK                     Allison Creek Hydro  61.084444
# 3              3    AK                             Anchorage 1  61.222100
# 4              4    AK                                  Angoon  57.447778
# 5              5    AK                                   Aniak  61.587500
# 6              6    AK                             Annex Creek  58.317600
# 7              7    AK                                Auke Bay  58.387500
# 8              8    AK                 Aurora Energy LLC Chena  64.847743
# 9              9    AK                                  Barrow  71.292000
# 10            10    AK           Battery Energy Storage System  64.816700
# 11            11    AK                            Beaver Falls  55.379750
# ...

# %%
plt.scatter(df['capacity_MW'],df['production_GWh'])
plt.show()

# %%
df1=pd.read_csv('storage_data.csv')
df1
# Out:
#      Unnamed: 0                                               name        lat  \
# 0             0  PG&E Advanced Underground Compressed Air Energ...  37.917594
# 1             1            Next Gen CAES using Steel Piping - NYPA  40.728224
# 2             2              Lake Elsinore Advanced Pumped Storage  33.668077
# 3             3             NYSEG Seneca/Watkins Glen CAES Project  42.415934
# 4             4  Con Edison/Eos Energy Storage Distributed Ener...  40.714353
# 5             5                          Apex Bethel Energy Center  31.835445
# 6             6                            Eldorado Pumped Storage  36.079561
# 7             7                          Prineville Pumped Storage  44.097813
# 8             8               Advanced Rail Energy Storage Nevada   36.208294
# 9             9  SolarCity / Tesla / Princeton Power Grid Servi...  37.548270
# 10           10  SolarCity / Tesla / Princeton Power EV Chargin...  37.548270
# ...

# %%
_
